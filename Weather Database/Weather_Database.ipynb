# %%
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime
import pandas as pd
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple. 
coordinates = zip(lats, lngs)

# %%
cities = []
for coordinate in coordinates:
    city = (citipy.nearest_city(coordinate[0], coordinate[1]).city_name)
    
    if city not in cities:
        cities.append(city)
print(len(cities))
# Out:
# 777

# %%
print(cities)
# Out:
# ['karlskrona', 'kamenka', 'saleaula', 'pevek', 'puerto ayora', 'port alfred', 'ahipara', 'vaini', 'butaritari', 'rikitea', 'hermanus', 'formoso do araguaia', 'tiksi', 'saryshagan', 'saint anthony', 'cervia', 'pedasi', 'cherskiy', 'dikson', 'thompson', 'aklavik', 'namibe', 'mar del plata', 'illoqqortoormiut', 'bluff', 'lorengau', 'mahebourg', 'ushuaia', 'voznesenye', 'leningradskiy', 'vestmanna', 'punta arenas', 'yulara', 'yavatmal', 'tasiilaq', 'bredasdorp', 'adrar', 'tocopilla', 'meyungs', 'port macquarie', 'anchorage', 'walvis bay', 'knysna', 'grand gaube', 'zhangjiakou', 'kichera', 'arroyo', 'nizhneyansk', 'saskylakh', 'atuona', 'new norfolk', 'port-gentil', 'busselton', 'arraial do cabo', 'tecoanapa', 'barrow', 'vryburg', 'itarema', 'port hedland', 'sabha', 'beckley', 'bambous virieux', 'digby', 'lethem', 'talnakh', 'clyde river', 'batsfjord', 'imeni stepana razina', 'terrace', 'nanortalik', 'verkhnyaya inta', 'taolanaro', 'caravelas', 'hilo', 'slavyanka', 'guerrero negro', 'kapaa', 'norman wells', 'victoria', 'qaanaaq', 'saint-philippe', 'namatanai', 'yichun', 'maniitsoq', 'tura', 'bernalillo', 'port elizabeth', 'saint george', 'thayetmyo', 'lagoa', 'yenagoa', 'wonthaggi', 'bathsheba', 'cape town', 'lebu', 'mys shmidta', 'sindand', 'samarai', 'elko', 'tombouctou', 'georgetown', 'kodiak', 'jamestown', 'makurdi', 'kamenskoye', 'tomatlan', 'faanui', 'sao joao da barra', 'cabo san lucas', 'east london', 'albany', 'isangel', 'casablanca', 'pandoh', 'amderma', 'yerbogachen', 'avarua', 'mogzon', 'mayo', 'mataura', 'mehamn', 'iwaki', 'bujumbura', 'robertsport', 'neuquen', 'sao filipe', 'kanniyakumari', 'provideniya', 'saint-francois', 'los llanos de aridane', 'carnarvon', 'goundam', 'nara', 'colac', 'kuche', 'qitaihe', 'araouane', 'airai', 'hithadhoo', 'yellowknife', 'akdepe', 'marcona', 'tres lagoas', 'suffolk', 'shache', 'lake city', 'khatanga', 'la ciotat', 'nuuk', 'chuy', 'cagayan de tawi-tawi', 'batagay-alyta', 'mwinilunga', 'rongcheng', 'beringovskiy', 'pangnirtung', 'malindi', 'upernavik', 'motril', 'aquiraz', 'ancud', 'attawapiskat', 'qui nhon', 'luderitz', 'margate', 'marsa matruh', 'ilulissat', 'arlit', 'natal', 'esperance', 'longyearbyen', 'esmeralda', 'shelburne', 'nanakuli', 'lasa', 'port blair', 'tikaitnagar', 'bengkulu', 'wattegama', 'willowmore', 'inhambane', 'tezu', 'kruisfontein', 'solenzo', 'kalabo', 'vestmannaeyjar', 'kavaratti', 'beinamar', 'gladstone', 'hobart', 'roebourne', 'istok', 'abu dhabi', 'cidreira', 'chokurdakh', 'ponta do sol', 'la ronge', 'porterville', 'tarko-sale', 'yinchuan', 'sentyabrskiy', 'pascagoula', 'nouadhibou', 'souillac', 'cockburn town', 'san patricio', 'barentsburg', 'padang', 'puri', 'baherden', 'praya', 'laguna', 'sug-aksy', 'hauterive', 'kavieng', 'kedougou', 'ribeira grande', 'fortuna', 'bethel', 'hofn', 'grindavik', 'hasaki', 'popondetta', 'benguela', 'korcula', 'yumen', 'pizarro', 'beidao', 'itacare', 'havelock', 'praia da vitoria', 'sampit', 'grand baie', 'rolim de moura', 'lompoc', 'golden', 'pechora', 'paita', 'nuevo progreso', 'sao felix do xingu', 'belushya guba', 'nikolskoye', 'hit', 'pangai', 'rawannawi', 'inirida', 'torbay', 'altamira', 'umm kaddadah', 'san cristobal', 'chingirlau', 'riachao', 'zachagansk', 'giyani', 'markova', 'castro', 'poddorye', 'homa bay', 'deputatskiy', 'sogdiondon', 'newburgh', 'whitehorse', 'kaduqli', 'svetlaya', 'savalou', 'great bend', 'tir pol', 'berekum', 'olinda', 'sitka', 'port lincoln', 'vicuna', 'acapulco', 'necochea', 'jujuy', 'vao', 'lincoln', 'mascote', 'hatta', 'oranjemund', 'camacha', 'klaksvik', 'saldanha', 'estelle', 'meadow lake', 'nanhai', 'along', 'tawkar', 'haverfordwest', 'kandrian', 'aktash', 'qaqortoq', 'dekoa', 'chicama', 'borlange', 'lulea', 'pisco', 'carbonia', 'mahon', 'golyshmanovo', 'little current', 'henties bay', 'astana', 'cap-aux-meules', 'bourail', 'nelson bay', 'aksarka', 'storsteinnes', 'mazatlan', 'omsukchan', 'kropotkin', 'labutta', 'skalistyy', 'alekseyevsk', 'champerico', 'mitsamiouli', 'coahuayana', 'olafs ...

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# city_url = f"{url}&q=saint-augustin"
# print(city_url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description":city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=karlskrona
# Processing Record 1 of Set 1 | karlskrona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kamenka
# Processing Record 2 of Set 1 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=saleaula
# Processing Record 3 of Set 1 | saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=pevek
# Processing Record 4 of Set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=puerto+ayora
# Processing Record 5 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=port+alfred
# Processing Record 6 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ahipara
# Processing Record 7 of Set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=vaini
# Processing Record 8 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=butaritari
# Processing Record 9 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=rikitea
# Processing Record 10 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=hermanus
# Processing Record 11 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=formoso+do+araguaia
# Processing Record 12 of Set 1 | formoso do araguaia
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tiksi
# Processing Record 13 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=saryshagan
# Processing Record 14 of Set 1 | saryshagan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=saint+anthony
# Processing Record 15 of Set 1 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=cervia
# Processing Record 16 of Set 1 | cervia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=pedasi
# Processing Record 17 of Set 1 | pedasi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=cherskiy
# Processing Record 18 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=dikson
# Processing Record 19 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=thompson
# Processing Record 20 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=aklavik
# Processing Record 21 of Set 1 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=namibe
# Processing Record 22 of Set 1 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mar+del+plata
# Processing Record 23 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=illoqqortoormiut
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bluff
# Processing Record 25 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lorengau
# Processing Record 26 of Set 1 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mahebourg
# Processing Record 27 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ushuaia
# Processing Record 28 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=voznesenye
# Processing Record 29 of Set 1 | voznesenye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=leningradskiy
# Processing Record 30 of Set 1 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=vestmanna
# Processing Record 31 of Set 1 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=punta+arenas
# Processing Record 32 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=yulara
# Processing Record 33 of Set 1 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=yavatmal
# Processing Record 34 of Set 1 | yavatmal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tasiilaq
# Processing Record 35 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bredasdorp
# Processing Record 36 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=adrar
# Processing Record 37 of Set 1 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tocopilla
# Processing Record 38 of Set 1 | tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=meyungs
# Processing Record 39 of Set 1 | meyungs
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=port+macquarie
# Processing Record 40 of Set 1 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=anchorage
# Processing Record 41 of Set 1 | anchorage
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=walvis+bay
# Processing Record 42 of Set 1 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=knysna
# Processing Record 43 of Set 1 | knysna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=grand+gaube
# Processing Record 44 of Set 1 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=zhangjiakou
# Processing Record 45 of Set 1 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kichera
# Processing Record 46 of Set 1 | kichera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=arroyo
# Processing Record 47 of Set 1 | arroyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nizhneyansk
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=saskylakh
# Processing Record 49 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=atuona
# Processing Record 50 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=new+norfolk
# Processing Record 1 of Set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=port-gentil
# Processing Record 2 of Set 2 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=busselton
# Processing Record 3 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=arraial+do+cabo
# Processing Record 4 of Set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tecoanapa
# Processing Record 5 of Set 2 | tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=barrow
# Processing Record 6 of Set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=vryburg
# Processing Record 7 of Set 2 | vryburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=itarema
# Processing Record 8 of Set 2 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=port+hedland
# Processing Record 9 of Set 2 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sabha
# Processing Record 10 of Set 2 | sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=beckley
# Processing Record 11 of Set 2 | beckley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bambous+virieux
# Processing Record 12 of Set 2 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=digby
# Processing Record 13 of Set 2 | digby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lethem
# Processing Record 14 of Set 2 | lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=talnakh
# Processing Record 15 of Set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=clyde+river
# Processing Record 16 of Set 2 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=batsfjord
# Processing Record 17 of Set 2 | batsfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=imeni+stepana+razina
# Processing Record 18 of Set 2 | imeni stepana razina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=terrace
# Processing Record 19 of Set 2 | terrace
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nanortalik
# Processing Record 20 of Set 2 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=verkhnyaya+inta
# Processing Record 21 of Set 2 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=taolanaro
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=caravelas
# Processing Record 23 of Set 2 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=hilo
# Processing Record 24 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=slavyanka
# Processing Record 25 of Set 2 | slavyanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=guerrero+negro
# Processing Record 26 of Set 2 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kapaa
# Processing Record 27 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=norman+wells
# Processing Record 28 of Set 2 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=victoria
# Processing Record 29 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=qaanaaq
# Processing Record 30 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=saint-philippe
# Processing Record 31 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=namatanai
# Processing Record 32 of Set 2 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=yichun
# Processing Record 33 of Set 2 | yichun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=maniitsoq
# Processing Record 34 of Set 2 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tura
# Processing Record 35 of Set 2 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bernalillo
# Processing Record 36 of Set 2 | bernalillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=port+elizabeth
# Processing Record 37 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=saint+george
# Processing Record 38 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=thayetmyo
# Processing Record 39 of Set 2 | thayetmyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lagoa
# Processing Record 40 of Set 2 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=yenagoa
# Processing Record 41 of Set 2 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=wonthaggi
# Processing Record 42 of Set 2 | wonthaggi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bathsheba
# Processing Record 43 of Set 2 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=cape+town
# Processing Record 44 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lebu
# Processing Record 45 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mys+shmidta
# Processing Record 46 of Set 2 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sindand
# Processing Record 47 of Set 2 | sindand
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=samarai
# Processing Record 48 of Set 2 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=elko
# Processing Record 49 of Set 2 | elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tombouctou
# Processing Record 50 of Set 2 | tombouctou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=georgetown
# Processing Record 1 of Set 3 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kodiak
# Processing Record 2 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=jamestown
# Processing Record 3 of Set 3 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=makurdi
# Processing Record 4 of Set 3 | makurdi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kamenskoye
# Processing Record 5 of Set 3 | kamenskoye
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tomatlan
# Processing Record 6 of Set 3 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=faanui
# Processing Record 7 of Set 3 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sao+joao+da+barra
# Processing Record 8 of Set 3 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=cabo+san+lucas
# Processing Record 9 of Set 3 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=east+london
# Processing Record 10 of Set 3 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=albany
# Processing Record 11 of Set 3 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=isangel
# Processing Record 12 of Set 3 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=casablanca
# Processing Record 13 of Set 3 | casablanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=pandoh
# Processing Record 14 of Set 3 | pandoh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=amderma
# Processing Record 15 of Set 3 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=yerbogachen
# Processing Record 16 of Set 3 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=avarua
# Processing Record 17 of Set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mogzon
# Processing Record 18 of Set 3 | mogzon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mayo
# Processing Record 19 of Set 3 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mataura
# Processing Record 20 of Set 3 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mehamn
# Processing Record 21 of Set 3 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=iwaki
# Processing Record 22 of Set 3 | iwaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bujumbura
# Processing Record 23 of Set 3 | bujumbura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=robertsport
# Processing Record 24 of Set 3 | robertsport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=neuquen
# Processing Record 25 of Set 3 | neuquen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sao+filipe
# Processing Record 26 of Set 3 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kanniyakumari
# Processing Record 27 of Set 3 | kanniyakumari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=provideniya
# Processing Record 28 of Set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=saint-francois
# Processing Record 29 of Set 3 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=los+llanos+de+aridane
# Processing Record 30 of Set 3 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=carnarvon
# Processing Record 31 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=goundam
# Processing Record 32 of Set 3 | goundam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nara
# Processing Record 33 of Set 3 | nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=colac
# Processing Record 34 of Set 3 | colac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kuche
# Processing Record 35 of Set 3 | kuche
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=qitaihe
# Processing Record 36 of Set 3 | qitaihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=araouane
# Processing Record 37 of Set 3 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=airai
# Processing Record 38 of Set 3 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=hithadhoo
# Processing Record 39 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=yellowknife
# Processing Record 40 of Set 3 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=akdepe
# Processing Record 41 of Set 3 | akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=marcona
# Processing Record 42 of Set 3 | marcona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tres+lagoas
# Processing Record 43 of Set 3 | tres lagoas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=suffolk
# Processing Record 44 of Set 3 | suffolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=shache
# Processing Record 45 of Set 3 | shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lake+city
# Processing Record 46 of Set 3 | lake city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=khatanga
# Processing Record 47 of Set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=la+ciotat
# Processing Record 48 of Set 3 | la ciotat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nuuk
# Processing Record 49 of Set 3 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=chuy
# Processing Record 50 of Set 3 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=cagayan+de+tawi-tawi
# Processing Record 1 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=batagay-alyta
# Processing Record 2 of Set 4 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mwinilunga
# Processing Record 3 of Set 4 | mwinilunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=rongcheng
# Processing Record 4 of Set 4 | rongcheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=beringovskiy
# Processing Record 5 of Set 4 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=pangnirtung
# Processing Record 6 of Set 4 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=malindi
# Processing Record 7 of Set 4 | malindi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=upernavik
# Processing Record 8 of Set 4 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=motril
# Processing Record 9 of Set 4 | motril
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=aquiraz
# Processing Record 10 of Set 4 | aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ancud
# Processing Record 11 of Set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=attawapiskat
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=qui+nhon
# Processing Record 13 of Set 4 | qui nhon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=luderitz
# Processing Record 14 of Set 4 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=margate
# Processing Record 15 of Set 4 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=marsa+matruh
# Processing Record 16 of Set 4 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ilulissat
# Processing Record 17 of Set 4 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=arlit
# Processing Record 18 of Set 4 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=natal
# Processing Record 19 of Set 4 | natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=esperance
# Processing Record 20 of Set 4 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=longyearbyen
# Processing Record 21 of Set 4 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=esmeralda
# Processing Record 22 of Set 4 | esmeralda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=shelburne
# Processing Record 23 of Set 4 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nanakuli
# Processing Record 24 of Set 4 | nanakuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lasa
# Processing Record 25 of Set 4 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=port+blair
# Processing Record 26 of Set 4 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tikaitnagar
# Processing Record 27 of Set 4 | tikaitnagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bengkulu
# Processing Record 28 of Set 4 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=wattegama
# Processing Record 29 of Set 4 | wattegama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=willowmore
# Processing Record 30 of Set 4 | willowmore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=inhambane
# Processing Record 31 of Set 4 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tezu
# Processing Record 32 of Set 4 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kruisfontein
# Processing Record 33 of Set 4 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=solenzo
# Processing Record 34 of Set 4 | solenzo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kalabo
# Processing Record 35 of Set 4 | kalabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=vestmannaeyjar
# Processing Record 36 of Set 4 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kavaratti
# Processing Record 37 of Set 4 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=beinamar
# Processing Record 38 of Set 4 | beinamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=gladstone
# Processing Record 39 of Set 4 | gladstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=hobart
# Processing Record 40 of Set 4 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=roebourne
# Processing Record 41 of Set 4 | roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=istok
# Processing Record 42 of Set 4 | istok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=abu+dhabi
# Processing Record 43 of Set 4 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=cidreira
# Processing Record 44 of Set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=chokurdakh
# Processing Record 45 of Set 4 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ponta+do+sol
# Processing Record 46 of Set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=la+ronge
# Processing Record 47 of Set 4 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=porterville
# Processing Record 48 of Set 4 | porterville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tarko-sale
# Processing Record 49 of Set 4 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=yinchuan
# Processing Record 50 of Set 4 | yinchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sentyabrskiy
# Processing Record 1 of Set 5 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=pascagoula
# Processing Record 2 of Set 5 | pascagoula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nouadhibou
# Processing Record 3 of Set 5 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=souillac
# Processing Record 4 of Set 5 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=cockburn+town
# Processing Record 5 of Set 5 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=san+patricio
# Processing Record 6 of Set 5 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=barentsburg
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=padang
# Processing Record 8 of Set 5 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=puri
# Processing Record 9 of Set 5 | puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=baherden
# Processing Record 10 of Set 5 | baherden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=praya
# Processing Record 11 of Set 5 | praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=laguna
# Processing Record 12 of Set 5 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sug-aksy
# Processing Record 13 of Set 5 | sug-aksy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=hauterive
# Processing Record 14 of Set 5 | hauterive
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kavieng
# Processing Record 15 of Set 5 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kedougou
# Processing Record 16 of Set 5 | kedougou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ribeira+grande
# Processing Record 17 of Set 5 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=fortuna
# Processing Record 18 of Set 5 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bethel
# Processing Record 19 of Set 5 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=hofn
# Processing Record 20 of Set 5 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=grindavik
# Processing Record 21 of Set 5 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=hasaki
# Processing Record 22 of Set 5 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=popondetta
# Processing Record 23 of Set 5 | popondetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=benguela
# Processing Record 24 of Set 5 | benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=korcula
# Processing Record 25 of Set 5 | korcula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=yumen
# Processing Record 26 of Set 5 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=pizarro
# Processing Record 27 of Set 5 | pizarro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=beidao
# Processing Record 28 of Set 5 | beidao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=itacare
# Processing Record 29 of Set 5 | itacare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=havelock
# Processing Record 30 of Set 5 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=praia+da+vitoria
# Processing Record 31 of Set 5 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sampit
# Processing Record 32 of Set 5 | sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=grand+baie
# Processing Record 33 of Set 5 | grand baie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=rolim+de+moura
# Processing Record 34 of Set 5 | rolim de moura
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lompoc
# Processing Record 35 of Set 5 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=golden
# Processing Record 36 of Set 5 | golden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=pechora
# Processing Record 37 of Set 5 | pechora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=paita
# Processing Record 38 of Set 5 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nuevo+progreso
# Processing Record 39 of Set 5 | nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sao+felix+do+xingu
# Processing Record 40 of Set 5 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=belushya+guba
# Processing Record 41 of Set 5 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nikolskoye
# Processing Record 42 of Set 5 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=hit
# Processing Record 43 of Set 5 | hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=pangai
# Processing Record 44 of Set 5 | pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=rawannawi
# Processing Record 45 of Set 5 | rawannawi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=inirida
# Processing Record 46 of Set 5 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=torbay
# Processing Record 47 of Set 5 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=altamira
# Processing Record 48 of Set 5 | altamira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=umm+kaddadah
# Processing Record 49 of Set 5 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=san+cristobal
# Processing Record 50 of Set 5 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=chingirlau
# Processing Record 1 of Set 6 | chingirlau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=riachao
# Processing Record 2 of Set 6 | riachao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=zachagansk
# Processing Record 3 of Set 6 | zachagansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=giyani
# Processing Record 4 of Set 6 | giyani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=markova
# Processing Record 5 of Set 6 | markova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=castro
# Processing Record 6 of Set 6 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=poddorye
# Processing Record 7 of Set 6 | poddorye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=homa+bay
# Processing Record 8 of Set 6 | homa bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=deputatskiy
# Processing Record 9 of Set 6 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sogdiondon
# Processing Record 10 of Set 6 | sogdiondon
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=newburgh
# Processing Record 11 of Set 6 | newburgh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=whitehorse
# Processing Record 12 of Set 6 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kaduqli
# Processing Record 13 of Set 6 | kaduqli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=svetlaya
# Processing Record 14 of Set 6 | svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=savalou
# Processing Record 15 of Set 6 | savalou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=great+bend
# Processing Record 16 of Set 6 | great bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tir+pol
# Processing Record 17 of Set 6 | tir pol
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=berekum
# Processing Record 18 of Set 6 | berekum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=olinda
# Processing Record 19 of Set 6 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sitka
# Processing Record 20 of Set 6 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=port+lincoln
# Processing Record 21 of Set 6 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=vicuna
# Processing Record 22 of Set 6 | vicuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=acapulco
# Processing Record 23 of Set 6 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=necochea
# Processing Record 24 of Set 6 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=jujuy
# Processing Record 25 of Set 6 | jujuy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=vao
# Processing Record 26 of Set 6 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lincoln
# Processing Record 27 of Set 6 | lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mascote
# Processing Record 28 of Set 6 | mascote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=hatta
# Processing Record 29 of Set 6 | hatta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=oranjemund
# Processing Record 30 of Set 6 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=camacha
# Processing Record 31 of Set 6 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=klaksvik
# Processing Record 32 of Set 6 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=saldanha
# Processing Record 33 of Set 6 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=estelle
# Processing Record 34 of Set 6 | estelle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=meadow+lake
# Processing Record 35 of Set 6 | meadow lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nanhai
# Processing Record 36 of Set 6 | nanhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=along
# Processing Record 37 of Set 6 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tawkar
# Processing Record 38 of Set 6 | tawkar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=haverfordwest
# Processing Record 39 of Set 6 | haverfordwest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kandrian
# Processing Record 40 of Set 6 | kandrian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=aktash
# Processing Record 41 of Set 6 | aktash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=qaqortoq
# Processing Record 42 of Set 6 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=dekoa
# Processing Record 43 of Set 6 | dekoa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=chicama
# Processing Record 44 of Set 6 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=borlange
# Processing Record 45 of Set 6 | borlange
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lulea
# Processing Record 46 of Set 6 | lulea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=pisco
# Processing Record 47 of Set 6 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=carbonia
# Processing Record 48 of Set 6 | carbonia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mahon
# Processing Record 49 of Set 6 | mahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=golyshmanovo
# Processing Record 50 of Set 6 | golyshmanovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=little+current
# Processing Record 1 of Set 7 | little current
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=henties+bay
# Processing Record 2 of Set 7 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=astana
# Processing Record 3 of Set 7 | astana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=cap-aux-meules
# Processing Record 4 of Set 7 | cap-aux-meules
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bourail
# Processing Record 5 of Set 7 | bourail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nelson+bay
# Processing Record 6 of Set 7 | nelson bay
# ...
# Processing Record 26 of Set 14 | abu kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ronne
# Processing Record 27 of Set 14 | ronne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tupik
# Processing Record 28 of Set 14 | tupik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mastic+beach
# Processing Record 29 of Set 14 | mastic beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=fort+nelson
# Processing Record 30 of Set 14 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=maceio
# Processing Record 31 of Set 14 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lumphat
# Processing Record 32 of Set 14 | lumphat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=marystown
# Processing Record 33 of Set 14 | marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=plettenberg+bay
# Processing Record 34 of Set 14 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=buariki
# Processing Record 35 of Set 14 | buariki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=osorno
# Processing Record 36 of Set 14 | osorno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=carutapera
# Processing Record 37 of Set 14 | carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=miyako
# Processing Record 38 of Set 14 | miyako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=vila
# Processing Record 39 of Set 14 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=price
# Processing Record 40 of Set 14 | price
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=calog
# Processing Record 41 of Set 14 | calog
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nantucket
# Processing Record 42 of Set 14 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=seymchan
# Processing Record 43 of Set 14 | seymchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=praia
# Processing Record 44 of Set 14 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=caucaia
# Processing Record 45 of Set 14 | caucaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kedarnath
# Processing Record 46 of Set 14 | kedarnath
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=vila+franca+do+campo
# Processing Record 47 of Set 14 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=marienburg
# Processing Record 48 of Set 14 | marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=one+hundred+mile+house
# Processing Record 49 of Set 14 | one hundred mile house
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ardakan
# Processing Record 50 of Set 14 | ardakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=peniche
# Processing Record 1 of Set 15 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bargal
# Processing Record 2 of Set 15 | bargal
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mutsamudu
# Processing Record 3 of Set 15 | mutsamudu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kalemie
# Processing Record 4 of Set 15 | kalemie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ubinskoye
# Processing Record 5 of Set 15 | ubinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=taywarah
# Processing Record 6 of Set 15 | taywarah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=caronport
# Processing Record 7 of Set 15 | caronport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bemidji
# Processing Record 8 of Set 15 | bemidji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=divnogorsk
# Processing Record 9 of Set 15 | divnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mapiripan
# Processing Record 10 of Set 15 | mapiripan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=yeppoon
# Processing Record 11 of Set 15 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=noshiro
# Processing Record 12 of Set 15 | noshiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=palmer
# Processing Record 13 of Set 15 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=te+karaka
# Processing Record 14 of Set 15 | te karaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=harper
# Processing Record 15 of Set 15 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=anqing
# Processing Record 16 of Set 15 | anqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=boralday
# Processing Record 17 of Set 15 | boralday
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=zorya
# Processing Record 18 of Set 15 | zorya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=marsabit
# Processing Record 19 of Set 15 | marsabit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=amapa
# Processing Record 20 of Set 15 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=kilindoni
# Processing Record 21 of Set 15 | kilindoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=casa+nova
# Processing Record 22 of Set 15 | casa nova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=olenino
# Processing Record 23 of Set 15 | olenino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mundo+nuevo
# Processing Record 24 of Set 15 | mundo nuevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=muros
# Processing Record 25 of Set 15 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=rundu
# Processing Record 26 of Set 15 | rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=moussoro
# Processing Record 27 of Set 15 | moussoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tula
# Processing Record 28 of Set 15 | tula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=iwanai
# Processing Record 29 of Set 15 | iwanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=panguna
# Processing Record 30 of Set 15 | panguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=notse
# Processing Record 31 of Set 15 | notse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=yaring
# Processing Record 32 of Set 15 | yaring
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=palu
# Processing Record 33 of Set 15 | palu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=labrea
# Processing Record 34 of Set 15 | labrea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=gari
# Processing Record 35 of Set 15 | gari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nabire
# Processing Record 36 of Set 15 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mae+hong+son
# Processing Record 37 of Set 15 | mae hong son
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=milledgeville
# Processing Record 38 of Set 15 | milledgeville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=gravdal
# Processing Record 39 of Set 15 | gravdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=jabinyanah
# Processing Record 40 of Set 15 | jabinyanah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=plock
# Processing Record 41 of Set 15 | plock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=moses+lake
# Processing Record 42 of Set 15 | moses lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=louisbourg
# Processing Record 43 of Set 15 | louisbourg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=fasa
# Processing Record 44 of Set 15 | fasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=maraa
# Processing Record 45 of Set 15 | maraa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=negombo
# Processing Record 46 of Set 15 | negombo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nalut
# Processing Record 47 of Set 15 | nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tabiauea
# Processing Record 48 of Set 15 | tabiauea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=san+mateo+ixtatan
# Processing Record 49 of Set 15 | san mateo ixtatan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=grand+centre
# Processing Record 50 of Set 15 | grand centre
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=dujuma
# Processing Record 1 of Set 16 | dujuma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lamar
# Processing Record 2 of Set 16 | lamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=diego+de+almagro
# Processing Record 3 of Set 16 | diego de almagro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=strezhevoy
# Processing Record 4 of Set 16 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=khorramshahr
# Processing Record 5 of Set 16 | khorramshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=loa+janan
# Processing Record 6 of Set 16 | loa janan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=dwarka
# Processing Record 7 of Set 16 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=bom+jesus
# Processing Record 8 of Set 16 | bom jesus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=watsa
# Processing Record 9 of Set 16 | watsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=galle
# Processing Record 10 of Set 16 | galle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=nenjiang
# Processing Record 11 of Set 16 | nenjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=copiapo
# Processing Record 12 of Set 16 | copiapo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=wahiawa
# Processing Record 13 of Set 16 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ziarat
# Processing Record 14 of Set 16 | ziarat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tuatapere
# Processing Record 15 of Set 16 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=troyes
# Processing Record 16 of Set 16 | troyes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=road+town
# Processing Record 17 of Set 16 | road town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=sabang
# Processing Record 18 of Set 16 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tigil
# Processing Record 19 of Set 16 | tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=lannion
# Processing Record 20 of Set 16 | lannion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=ishikari
# Processing Record 21 of Set 16 | ishikari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=mangrul+pir
# Processing Record 22 of Set 16 | mangrul pir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=terrell
# Processing Record 23 of Set 16 | terrell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=forbes
# Processing Record 24 of Set 16 | forbes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=tarudant
# Processing Record 25 of Set 16 | tarudant
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=pedernales
# Processing Record 26 of Set 16 | pedernales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e18ee5fd60d311b0c2381b82a7162e3d&q=roald
# Processing Record 27 of Set 16 | roald
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Karlskrona  56.1616   15.5866     39.65        97         100
# 1       Kamenka  51.3223   42.7678     33.94        99         100
# 2         Pevek  69.7008  170.3133     -4.02        85           5
# 3  Puerto Ayora  -0.7393  -90.3518     76.55        95         100
# 4   Port Alfred -33.5906   26.8910     66.18        89          50
# 5       Ahipara -35.1667  173.1667     71.65        70          32
# 6         Vaini -21.2000 -175.2000     78.96        89          75
# 7    Butaritari   3.0707  172.7902     81.54        73          98
# 8       Rikitea -23.1203 -134.9692     77.76        64         100
# 9      Hermanus -34.4187   19.2345     56.80        86           2
#
#    Wind Speed Country       Description
# 0       18.88      SE   overcast clouds
# 1        9.62      RU              snow
# 2        2.59      RU         clear sky
# 3        8.01      EC   overcast clouds
# 4        1.01      ZA  scattered clouds
# 5        2.86      NZ  scattered clouds
# 6        6.91      TO     broken clouds
# 7       11.54      KI   overcast clouds
# 8        9.66      PF   overcast clouds
# 9        2.57      ZA         clear sky

# %%
print(city_data)
# Out:
# [{'City': 'Karlskrona', 'Lat': 56.1616, 'Lng': 15.5866, 'Max Temp': 39.65, 'Humidity': 97, 'Cloudiness': 100, 'Wind Speed': 18.88, 'Country': 'SE', 'Description': 'overcast clouds'}, {'City': 'Kamenka', 'Lat': 51.3223, 'Lng': 42.7678, 'Max Temp': 33.94, 'Humidity': 99, 'Cloudiness': 100, 'Wind Speed': 9.62, 'Country': 'RU', 'Description': 'snow'}, {'City': 'Pevek', 'Lat': 69.7008, 'Lng': 170.3133, 'Max Temp': -4.02, 'Humidity': 85, 'Cloudiness': 5, 'Wind Speed': 2.59, 'Country': 'RU', 'Description': 'clear sky'}, {'City': 'Puerto Ayora', 'Lat': -0.7393, 'Lng': -90.3518, 'Max Temp': 76.55, 'Humidity': 95, 'Cloudiness': 100, 'Wind Speed': 8.01, 'Country': 'EC', 'Description': 'overcast clouds'}, {'City': 'Port Alfred', 'Lat': -33.5906, 'Lng': 26.891, 'Max Temp': 66.18, 'Humidity': 89, 'Cloudiness': 50, 'Wind Speed': 1.01, 'Country': 'ZA', 'Description': 'scattered clouds'}, {'City': 'Ahipara', 'Lat': -35.1667, 'Lng': 173.1667, 'Max Temp': 71.65, 'Humidity': 70, 'Cloudiness': 32, 'Wind Speed': 2.86, 'Country': 'NZ', 'Description': 'scattered clouds'}, {'City': 'Vaini', 'Lat': -21.2, 'Lng': -175.2, 'Max Temp': 78.96, 'Humidity': 89, 'Cloudiness': 75, 'Wind Speed': 6.91, 'Country': 'TO', 'Description': 'broken clouds'}, {'City': 'Butaritari', 'Lat': 3.0707, 'Lng': 172.7902, 'Max Temp': 81.54, 'Humidity': 73, 'Cloudiness': 98, 'Wind Speed': 11.54, 'Country': 'KI', 'Description': 'overcast clouds'}, {'City': 'Rikitea', 'Lat': -23.1203, 'Lng': -134.9692, 'Max Temp': 77.76, 'Humidity': 64, 'Cloudiness': 100, 'Wind Speed': 9.66, 'Country': 'PF', 'Description': 'overcast clouds'}, {'City': 'Hermanus', 'Lat': -34.4187, 'Lng': 19.2345, 'Max Temp': 56.8, 'Humidity': 86, 'Cloudiness': 2, 'Wind Speed': 2.57, 'Country': 'ZA', 'Description': 'clear sky'}, {'City': 'Tiksi', 'Lat': 71.6872, 'Lng': 128.8694, 'Max Temp': 6.66, 'Humidity': 92, 'Cloudiness': 100, 'Wind Speed': 8.81, 'Country': 'RU', 'Description': 'overcast clouds'}, {'City': 'Saint Anthony', 'Lat': 45.0205, 'Lng': -93.218, 'Max Temp': 38.93, 'Humidity': 84, 'Cloudiness': 100, 'Wind Speed': 8.05, 'Country': 'US', 'Description': 'light rain'}, {'City': 'Cervia', 'Lat': 44.2657, 'Lng': 12.3427, 'Max Temp': 48.2, 'Humidity': 87, 'Cloudiness': 0, 'Wind Speed': 3.44, 'Country': 'IT', 'Description': 'clear sky'}, {'City': 'Pedasi', 'Lat': 7.5333, 'Lng': -80.0333, 'Max Temp': 78.06, 'Humidity': 78, 'Cloudiness': 100, 'Wind Speed': 6.11, 'Country': 'PA', 'Description': 'overcast clouds'}, {'City': 'Cherskiy', 'Lat': 68.75, 'Lng': 161.3, 'Max Temp': 1.96, 'Humidity': 85, 'Cloudiness': 100, 'Wind Speed': 3.15, 'Country': 'RU', 'Description': 'overcast clouds'}, {'City': 'Dikson', 'Lat': 73.5069, 'Lng': 80.5464, 'Max Temp': 2.34, 'Humidity': 94, 'Cloudiness': 81, 'Wind Speed': 9.71, 'Country': 'RU', 'Description': 'broken clouds'}, {'City': 'Thompson', 'Lat': 55.7435, 'Lng': -97.8558, 'Max Temp': 37.56, 'Humidity': 52, 'Cloudiness': 100, 'Wind Speed': 4.61, 'Country': 'CA', 'Description': 'overcast clouds'}, {'City': 'Aklavik', 'Lat': 68.2191, 'Lng': -135.0107, 'Max Temp': -5.89, 'Humidity': 89, 'Cloudiness': 100, 'Wind Speed': 10, 'Country': 'CA', 'Description': 'overcast clouds'}, {'City': 'Namibe', 'Lat': -15.1961, 'Lng': 12.1522, 'Max Temp': 69.78, 'Humidity': 81, 'Cloudiness': 90, 'Wind Speed': 9.26, 'Country': 'AO', 'Description': 'overcast clouds'}, {'City': 'Mar Del Plata', 'Lat': -38.0023, 'Lng': -57.5575, 'Max Temp': 55.42, 'Humidity': 61, 'Cloudiness': 0, 'Wind Speed': 14.97, 'Country': 'AR', 'Description': 'clear sky'}, {'City': 'Bluff', 'Lat': -46.6, 'Lng': 168.3333, 'Max Temp': 58.26, 'Humidity': 73, 'Cloudiness': 69, 'Wind Speed': 8.48, 'Country': 'NZ', 'Description': 'broken clouds'}, {'City': 'Lorengau', 'Lat': -2.0226, 'Lng': 147.2712, 'Max Temp': 84.67, 'Humidity': 69, 'Cloudiness': 83, 'Wind Speed': 5.5, 'Country': 'PG', 'Description': 'broken clouds'}, {'City': 'Mahebourg', 'Lat': -20.4081, 'Lng': 57.7, 'Max Temp': 79.25, 'Humidity': 83, 'Cloudiness': 40, 'Wind Speed': 11.5 ...

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
